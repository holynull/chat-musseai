# %%
from langgraph.prebuilt import create_react_agent
from dotenv import load_dotenv

load_dotenv(".env")
import nest_asyncio

nest_asyncio.apply()

# %%
import logging
from graphs.graph_swap import graph
from IPython.display import Image, display
from langchain_core.runnables.graph import MermaidDrawMethod

try:
    display(
        Image(
            graph.get_graph().draw_mermaid_png(draw_method=MermaidDrawMethod.PYPPETEER)
        )
    )
except Exception as e:
    # This requires some extra dependencies and is optional
    logging.error(e)
    # pass
# Out:
# INFO:pyppeteer.launcher:Browser listening on: ws://127.0.0.1:63896/devtools/browser/b80b6c66-9797-47f5-b6b8-a7d58b4d4c26
# INFO:pyppeteer.launcher:terminate chrome process...

# %%
from graphs.graph_wallet import graph
from IPython.display import Image, display

try:
    display(
        Image(
            graph.get_graph().draw_mermaid_png(draw_method=MermaidDrawMethod.PYPPETEER)
        )
    )
except Exception:
    # This requires some extra dependencies and is optional
    pass
# Out:
# INFO:pyppeteer.launcher:Browser listening on: ws://127.0.0.1:63918/devtools/browser/98bd0480-a10f-41cc-b365-fb03461c5852
# INFO:pyppeteer.launcher:terminate chrome process...

# %%
from graphs.graph_search import graph
from IPython.display import Image, display

try:
    display(
        Image(
            graph.get_graph().draw_mermaid_png(draw_method=MermaidDrawMethod.PYPPETEER)
        )
    )
except Exception:
    # This requires some extra dependencies and is optional
    pass
# Out:
# INFO:pyppeteer.launcher:Browser listening on: ws://127.0.0.1:63932/devtools/browser/f47d16cd-7846-4581-a33f-dfac5793541d
# INFO:pyppeteer.launcher:terminate chrome process...

# %%
from graphs.graph_quote import graph
from IPython.display import Image, display

try:
    display(
        Image(
            graph.get_graph().draw_mermaid_png(draw_method=MermaidDrawMethod.PYPPETEER)
        )
    )
except Exception:
    # This requires some extra dependencies and is optional
    pass
# Out:
# INFO:pyppeteer.launcher:Browser listening on: ws://127.0.0.1:63946/devtools/browser/21587369-5d4c-47f0-b40a-c723454e3543
# INFO:pyppeteer.launcher:terminate chrome process...

# %%
from graphs.graph_image import graph
from IPython.display import Image, display

try:
    display(
        Image(
            graph.get_graph().draw_mermaid_png(draw_method=MermaidDrawMethod.PYPPETEER)
        )
    )
except Exception:
    # This requires some extra dependencies and is optional
    pass
# Out:
# INFO:pyppeteer.launcher:Browser listening on: ws://127.0.0.1:63959/devtools/browser/92568a72-ed3b-4f94-a4a2-82e3ec6cb325
# INFO:pyppeteer.launcher:terminate chrome process...

# %%
from graphs.graph_infura import graph
from IPython.display import Image, display

try:
    display(
        Image(
            graph.get_graph().draw_mermaid_png(draw_method=MermaidDrawMethod.PYPPETEER)
        )
    )
except Exception:
    # This requires some extra dependencies and is optional
    pass
# Out:
# INFO:pyppeteer.launcher:Browser listening on: ws://127.0.0.1:63975/devtools/browser/1221959c-3e32-4acb-8578-5c014468417d
# INFO:pyppeteer.launcher:terminate chrome process...

# %%
from graphs.graph_crypto_portfolios import graph
from IPython.display import Image, display

try:
    display(
        Image(
            graph.get_graph().draw_mermaid_png(draw_method=MermaidDrawMethod.PYPPETEER)
        )
    )
except Exception:
    # This requires some extra dependencies and is optional
    pass
# Out:
# INFO:pyppeteer.launcher:Browser listening on: ws://127.0.0.1:63987/devtools/browser/1557f28e-400b-4238-bbac-6a78ad8ea45a
# INFO:pyppeteer.launcher:terminate chrome process...

# %%
from graphs.graph_chatbot import graph
from IPython.display import Image, display

try:
    display(
        Image(
            graph.get_graph().draw_mermaid_png(draw_method=MermaidDrawMethod.PYPPETEER)
        )
    )
except Exception:
    # This requires some extra dependencies and is optional
    pass
# Out:
# INFO:pyppeteer.launcher:Browser listening on: ws://127.0.0.1:64015/devtools/browser/5815c18d-1e11-456f-bbba-8778e25d9f02
# INFO:pyppeteer.launcher:terminate chrome process...

# %%
chunks = graph.astream_events(
    {
        "messages": {"type": "human", "content": "把这个地址上bsc的usdt余额增加到我的仓位里，0x25Dd4FD54a3c0C70cD780000D9a0eE90d93B8E85。"},
        "wallet_is_connected": True,
        "chain_id": 56,
        "wallet_address": "0x25Dd4FD54a3c0C70cD780000D9a0eE90d93B8E85",
        "time_zone": "Asia/Shanghai",
        "llm": "anthropic_claude_3_5_sonnet",
		"user_id":"9e01566644f488477d85d2f265cf8f2ca2605827790739034ae9e58f7efb3968"
    },
    version="v1",
    stream_mode="messages",
)
from typing import List
from langchain_core.messages import AIMessage

async for chunk in chunks:
    print(chunk)
    if chunk["event"] == "on_chain_stream":
        # print(chunk)
        if "data" in chunk:
            # print(chunk["data"])
            data = chunk["data"]
            # print(data["chunk"])
            # if "messages" in data["chunk"]:
            #     messages = data["chunk"]["messages"]
            #     # print(f"messages are {messages}")
            #     if isinstance(messages, List) and isinstance(messages[0], AIMessage):
            #         print(f"{messages[0].content[0]['text']}")
