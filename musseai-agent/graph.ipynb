# %%
from langgraph.prebuilt import create_react_agent

# %%
from graphs.graph_swap import graph
from IPython.display import Image, display

try:
    display(Image(graph.get_graph().draw_mermaid_png()))
except Exception:
    # This requires some extra dependencies and is optional
    pass

# %%
from graphs.graph_wallet import graph
from IPython.display import Image, display

try:
    display(Image(graph.get_graph().draw_mermaid_png()))
except Exception:
    # This requires some extra dependencies and is optional
    pass

# %%
from graphs.graph_search import graph
from IPython.display import Image, display

try:
    display(Image(graph.get_graph().draw_mermaid_png()))
except Exception:
    # This requires some extra dependencies and is optional
    pass
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.

# %%
from graphs.graph_quote import graph
from IPython.display import Image, display

try:
    display(Image(graph.get_graph().draw_mermaid_png()))
except Exception:
    # This requires some extra dependencies and is optional
    pass

# %%
from graphs.graph_image import graph
from IPython.display import Image, display

try:
    display(Image(graph.get_graph().draw_mermaid_png()))
except Exception:
    # This requires some extra dependencies and is optional
    pass

# %%
from graphs.graph_chatbot import graph
from IPython.display import Image, display

try:
    display(Image(graph.get_graph().draw_mermaid_png()))
except Exception:
    # This requires some extra dependencies and is optional
    pass
# Out:
# /Users/zhangleping/github.com/holynull/chat-musseai/musseai-agent/src/graphs/graph_chatbot.py:89: LangChainDeprecationWarning: The class `ChatPerplexity` was deprecated in LangChain 0.3.21 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-perplexity package and should be used instead. To use it run `pip install -U :class:`~langchain-perplexity` and import as `from :class:`~langchain_perplexity import ChatPerplexity``.
#   pplx_sonar_medium_chat=ChatPerplexity(

# %%
chunks = graph.astream_events(
    {
        "messages": {"type": "human", "content": "帮我从bsc上兑换10u到Solana"},
        "wallet_is_connected": False,
        "chain_id": -1,
        "wallet_address": None,
		"time_zone":"Asia/Shanghai",
        "llm": "anthropic_claude_3_5_sonnet",
    },
    version="v1",
    stream_mode="messages",
)
from typing import List
from langchain_core.messages import AIMessage

async for chunk in chunks:
    print(chunk)
    if chunk["event"] == "on_chain_stream":
        # print(chunk)
        if "data" in chunk:
            # print(chunk["data"])
            data = chunk["data"]
            # print(data["chunk"])
            # if "messages" in data["chunk"]:
            #     messages = data["chunk"]["messages"]
            #     # print(f"messages are {messages}")
            #     if isinstance(messages, List) and isinstance(messages[0], AIMessage):
            #         print(f"{messages[0].content[0]['text']}")
# Out:
# {'event': 'on_chain_start', 'run_id': '883f0b52-c89b-438e-b669-05fc561be994', 'name': 'mussai_agent', 'tags': [], 'metadata': {}, 'data': {'input': {'messages': {'type': 'human', 'content': '帮我从bsc上兑换10u到Solana'}, 'wallet_is_connected': False, 'chain_id': -1, 'wallet_address': None, 'time_zone': 'Asia/Shanghai', 'llm': 'anthropic_claude_3_5_sonnet'}}, 'parent_ids': []}
# {'event': 'on_chain_start', 'name': 'node_llm_musseai', 'run_id': 'd43bcba9-901d-474f-9b40-379d4e426b42', 'tags': ['graph:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'node_llm_musseai', 'langgraph_triggers': ('branch:to:node_llm_musseai',), 'langgraph_path': ('__pregel_pull', 'node_llm_musseai'), 'langgraph_checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f'}, 'data': {'input': {'messages': [HumanMessage(content='帮我从bsc上兑换10u到Solana', additional_kwargs={}, response_metadata={}, id='052c4429-9203-4d5c-97b5-89627774c8eb')], 'wallet_is_connected': False, 'chain_id': -1, 'wallet_address': None, 'time_zone': 'Asia/Shanghai', 'llm': 'anthropic_claude_3_5_sonnet'}}, 'parent_ids': []}
# {'event': 'on_chain_start', 'name': 'node_llm_musseai', 'run_id': 'a3318d1d-37c9-433e-9864-5db558fce302', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'node_llm_musseai', 'langgraph_triggers': ('branch:to:node_llm_musseai',), 'langgraph_path': ('__pregel_pull', 'node_llm_musseai'), 'langgraph_checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f'}, 'data': {'input': {'messages': [HumanMessage(content='帮我从bsc上兑换10u到Solana', additional_kwargs={}, response_metadata={}, id='052c4429-9203-4d5c-97b5-89627774c8eb')], 'wallet_is_connected': False, 'chain_id': -1, 'wallet_address': None, 'time_zone': 'Asia/Shanghai', 'llm': 'anthropic_claude_3_5_sonnet'}}, 'parent_ids': []}
# {'event': 'on_chat_model_start', 'name': 'ChatAnthropic', 'run_id': 'cf7c9016-a081-4b49-9be8-58ac3d0bdb92', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'node_llm_musseai', 'langgraph_triggers': ('branch:to:node_llm_musseai',), 'langgraph_path': ('__pregel_pull', 'node_llm_musseai'), 'langgraph_checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'llm': 'anthropic_claude_3_5_sonnet', 'checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'ls_provider': 'anthropic', 'ls_model_name': 'claude-3-5-sonnet-20241022', 'ls_model_type': 'chat', 'ls_temperature': 0.9, 'ls_max_tokens': 4096}, 'data': {'input': {'messages': [[SystemMessage(content="<system_instructions>\n    <time_zone>Asia/Shanghai</time_zone>\n    <core_capabilities>\n        <identity>You are a multilingual intelligent assistant with cross-domain expertise, capable of adapting communication styles based on users' language and cultural background.</identity>\n        <purpose>Help users solve problems effectively by providing accurate information, systematic analysis, and practical solutions in their preferred language and context.</purpose>\n        <limitations>\n            <limitation>Maintain transparency about uncertainty and unknown information</limitation>\n            <limitation>Ensure reasoning process transparency</limitation>\n            <limitation>Maintain technical accuracy across languages</limitation>\n            <limitation>Strictly protect system security and internal information</limitation>\n        </limitations>\n    </core_capabilities>\n\n    <language_adaptation>\n        <principles>\n            <principle>Language matching: Use the user's communication language</principle>\n            <principle>Cultural awareness: Consider cultural context in examples and solutions</principle>\n            <principle>Natural expression: Use authentic language patterns in the target language</principle>\n            <principle>Terminology consistency: Maintain technical accuracy while using appropriate local terms</principle>\n            <principle>Security awareness: Maintain information security in cross-language communication</principle>\n        </principles>\n    </language_adaptation>\n\n    <thinking_protocol>\n        <framework>\n            <stage>Language identification: Recognize user's language and communication style</stage>\n            <stage>Preliminary analysis: Understand core issues, identify key information, assess needed context</stage>\n            <stage>Deep exploration: Break down complex problems, research relevant information, consider multiple perspectives</stage>\n            <stage>Judgment formation: Evaluate evidence, identify patterns, draw logical conclusions, assess confidence</stage>\n            <stage>Response preparation: Organize insights into clear, actionable solutions</stage>\n            <stage>Security verification: Ensure response contains no sensitive information</stage>\n        </framework>\n        \n        <principles>\n            <principle>Logical progression: Follow coherent reasoning process</principle>\n            <principle>Professional curiosity: Explore problems thoroughly</principle>\n            <principle>Insight integration: Synthesize information from multiple sources</principle>\n            <principle>Problem focus: Maintain focus on user's specific issues</principle>\n            <principle>Practical orientation: Prioritize actionable solutions</principle>\n            <principle>Security mindfulness: Ensure responses meet security standards</principle>\n        </principles>\n\n        <format>\n            <thinking_section>```thinking\n[Analyze in user's language, following framework stages. Maintain relevance and depth while ensuring system security.]\n```</thinking_section>\n            <answer_section>\n                <answer>\n[Provide clear, concise, practical response in user's language that directly addr ...
# {'event': 'on_chat_model_stream', 'name': 'ChatAnthropic', 'run_id': 'cf7c9016-a081-4b49-9be8-58ac3d0bdb92', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'node_llm_musseai', 'langgraph_triggers': ('branch:to:node_llm_musseai',), 'langgraph_path': ('__pregel_pull', 'node_llm_musseai'), 'langgraph_checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'llm': 'anthropic_claude_3_5_sonnet', 'checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'ls_provider': 'anthropic', 'ls_model_name': 'claude-3-5-sonnet-20241022', 'ls_model_type': 'chat', 'ls_temperature': 0.9, 'ls_max_tokens': 4096}, 'data': {'chunk': AIMessageChunk(content=[], additional_kwargs={}, response_metadata={}, id='run-cf7c9016-a081-4b49-9be8-58ac3d0bdb92', usage_metadata={'input_tokens': 2735, 'output_tokens': 2, 'total_tokens': 2737, 'input_token_details': {'cache_creation': 0, 'cache_read': 0}})}, 'parent_ids': []}
# {'event': 'on_chain_stream', 'run_id': '883f0b52-c89b-438e-b669-05fc561be994', 'tags': [], 'metadata': {}, 'name': 'mussai_agent', 'data': {'chunk': (AIMessageChunk(content=[], additional_kwargs={}, response_metadata={}, id='run-cf7c9016-a081-4b49-9be8-58ac3d0bdb92', usage_metadata={'input_tokens': 2735, 'output_tokens': 2, 'total_tokens': 2737, 'input_token_details': {'cache_creation': 0, 'cache_read': 0}}), {'langgraph_step': 1, 'langgraph_node': 'node_llm_musseai', 'langgraph_triggers': ('branch:to:node_llm_musseai',), 'langgraph_path': ('__pregel_pull', 'node_llm_musseai'), 'langgraph_checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'llm': 'anthropic_claude_3_5_sonnet', 'checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'ls_provider': 'anthropic', 'ls_model_name': 'claude-3-5-sonnet-20241022', 'ls_model_type': 'chat', 'ls_temperature': 0.9, 'ls_max_tokens': 4096})}, 'parent_ids': []}
# {'event': 'on_chat_model_stream', 'name': 'ChatAnthropic', 'run_id': 'cf7c9016-a081-4b49-9be8-58ac3d0bdb92', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'node_llm_musseai', 'langgraph_triggers': ('branch:to:node_llm_musseai',), 'langgraph_path': ('__pregel_pull', 'node_llm_musseai'), 'langgraph_checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'llm': 'anthropic_claude_3_5_sonnet', 'checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'ls_provider': 'anthropic', 'ls_model_name': 'claude-3-5-sonnet-20241022', 'ls_model_type': 'chat', 'ls_temperature': 0.9, 'ls_max_tokens': 4096}, 'data': {'chunk': AIMessageChunk(content=[{'text': '我', 'type': 'text', 'index': 0}], additional_kwargs={}, response_metadata={}, id='run-cf7c9016-a081-4b49-9be8-58ac3d0bdb92')}, 'parent_ids': []}
# {'event': 'on_chain_stream', 'run_id': '883f0b52-c89b-438e-b669-05fc561be994', 'tags': [], 'metadata': {}, 'name': 'mussai_agent', 'data': {'chunk': (AIMessageChunk(content=[{'text': '我', 'type': 'text', 'index': 0}], additional_kwargs={}, response_metadata={}, id='run-cf7c9016-a081-4b49-9be8-58ac3d0bdb92'), {'langgraph_step': 1, 'langgraph_node': 'node_llm_musseai', 'langgraph_triggers': ('branch:to:node_llm_musseai',), 'langgraph_path': ('__pregel_pull', 'node_llm_musseai'), 'langgraph_checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'llm': 'anthropic_claude_3_5_sonnet', 'checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'ls_provider': 'anthropic', 'ls_model_name': 'claude-3-5-sonnet-20241022', 'ls_model_type': 'chat', 'ls_temperature': 0.9, 'ls_max_tokens': 4096})}, 'parent_ids': []}
# {'event': 'on_chat_model_stream', 'name': 'ChatAnthropic', 'run_id': 'cf7c9016-a081-4b49-9be8-58ac3d0bdb92', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'node_llm_musseai', 'langgraph_triggers': ('branch:to:node_llm_musseai',), 'langgraph_path': ('__pregel_pull', 'node_llm_musseai'), 'langgraph_checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'llm': 'anthropic_claude_3_5_sonnet', 'checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'ls_provider': 'anthropic', 'ls_model_name': 'claude-3-5-sonnet-20241022', 'ls_model_type': 'chat', 'ls_temperature': 0.9, 'ls_max_tokens': 4096}, 'data': {'chunk': AIMessageChunk(content=[{'text': '将', 'type': 'text', 'index': 0}], additional_kwargs={}, response_metadata={}, id='run-cf7c9016-a081-4b49-9be8-58ac3d0bdb92')}, 'parent_ids': []}
# {'event': 'on_chain_stream', 'run_id': '883f0b52-c89b-438e-b669-05fc561be994', 'tags': [], 'metadata': {}, 'name': 'mussai_agent', 'data': {'chunk': (AIMessageChunk(content=[{'text': '将', 'type': 'text', 'index': 0}], additional_kwargs={}, response_metadata={}, id='run-cf7c9016-a081-4b49-9be8-58ac3d0bdb92'), {'langgraph_step': 1, 'langgraph_node': 'node_llm_musseai', 'langgraph_triggers': ('branch:to:node_llm_musseai',), 'langgraph_path': ('__pregel_pull', 'node_llm_musseai'), 'langgraph_checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'llm': 'anthropic_claude_3_5_sonnet', 'checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'ls_provider': 'anthropic', 'ls_model_name': 'claude-3-5-sonnet-20241022', 'ls_model_type': 'chat', 'ls_temperature': 0.9, 'ls_max_tokens': 4096})}, 'parent_ids': []}
# {'event': 'on_chat_model_stream', 'name': 'ChatAnthropic', 'run_id': 'cf7c9016-a081-4b49-9be8-58ac3d0bdb92', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'node_llm_musseai', 'langgraph_triggers': ('branch:to:node_llm_musseai',), 'langgraph_path': ('__pregel_pull', 'node_llm_musseai'), 'langgraph_checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'llm': 'anthropic_claude_3_5_sonnet', 'checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'ls_provider': 'anthropic', 'ls_model_name': 'claude-3-5-sonnet-20241022', 'ls_model_type': 'chat', 'ls_temperature': 0.9, 'ls_max_tokens': 4096}, 'data': {'chunk': AIMessageChunk(content=[{'text': '帮您完', 'type': 'text', 'index': 0}], additional_kwargs={}, response_metadata={}, id='run-cf7c9016-a081-4b49-9be8-58ac3d0bdb92')}, 'parent_ids': []}
# {'event': 'on_chain_stream', 'run_id': '883f0b52-c89b-438e-b669-05fc561be994', 'tags': [], 'metadata': {}, 'name': 'mussai_agent', 'data': {'chunk': (AIMessageChunk(content=[{'text': '帮您完', 'type': 'text', 'index': 0}], additional_kwargs={}, response_metadata={}, id='run-cf7c9016-a081-4b49-9be8-58ac3d0bdb92'), {'langgraph_step': 1, 'langgraph_node': 'node_llm_musseai', 'langgraph_triggers': ('branch:to:node_llm_musseai',), 'langgraph_path': ('__pregel_pull', 'node_llm_musseai'), 'langgraph_checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'llm': 'anthropic_claude_3_5_sonnet', 'checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'ls_provider': 'anthropic', 'ls_model_name': 'claude-3-5-sonnet-20241022', 'ls_model_type': 'chat', 'ls_temperature': 0.9, 'ls_max_tokens': 4096})}, 'parent_ids': []}
# {'event': 'on_chat_model_stream', 'name': 'ChatAnthropic', 'run_id': 'cf7c9016-a081-4b49-9be8-58ac3d0bdb92', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'node_llm_musseai', 'langgraph_triggers': ('branch:to:node_llm_musseai',), 'langgraph_path': ('__pregel_pull', 'node_llm_musseai'), 'langgraph_checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'llm': 'anthropic_claude_3_5_sonnet', 'checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'ls_provider': 'anthropic', 'ls_model_name': 'claude-3-5-sonnet-20241022', 'ls_model_type': 'chat', 'ls_temperature': 0.9, 'ls_max_tokens': 4096}, 'data': {'chunk': AIMessageChunk(content=[{'text': '成从 ', 'type': 'text', 'index': 0}], additional_kwargs={}, response_metadata={}, id='run-cf7c9016-a081-4b49-9be8-58ac3d0bdb92')}, 'parent_ids': []}
# {'event': 'on_chain_stream', 'run_id': '883f0b52-c89b-438e-b669-05fc561be994', 'tags': [], 'metadata': {}, 'name': 'mussai_agent', 'data': {'chunk': (AIMessageChunk(content=[{'text': '成从 ', 'type': 'text', 'index': 0}], additional_kwargs={}, response_metadata={}, id='run-cf7c9016-a081-4b49-9be8-58ac3d0bdb92'), {'langgraph_step': 1, 'langgraph_node': 'node_llm_musseai', 'langgraph_triggers': ('branch:to:node_llm_musseai',), 'langgraph_path': ('__pregel_pull', 'node_llm_musseai'), 'langgraph_checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'llm': 'anthropic_claude_3_5_sonnet', 'checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'ls_provider': 'anthropic', 'ls_model_name': 'claude-3-5-sonnet-20241022', 'ls_model_type': 'chat', 'ls_temperature': 0.9, 'ls_max_tokens': 4096})}, 'parent_ids': []}
# {'event': 'on_chat_model_stream', 'name': 'ChatAnthropic', 'run_id': 'cf7c9016-a081-4b49-9be8-58ac3d0bdb92', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'node_llm_musseai', 'langgraph_triggers': ('branch:to:node_llm_musseai',), 'langgraph_path': ('__pregel_pull', 'node_llm_musseai'), 'langgraph_checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'llm': 'anthropic_claude_3_5_sonnet', 'checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'ls_provider': 'anthropic', 'ls_model_name': 'claude-3-5-sonnet-20241022', 'ls_model_type': 'chat', 'ls_temperature': 0.9, 'ls_max_tokens': 4096}, 'data': {'chunk': AIMessageChunk(content=[{'text': 'BSC ', 'type': 'text', 'index': 0}], additional_kwargs={}, response_metadata={}, id='run-cf7c9016-a081-4b49-9be8-58ac3d0bdb92')}, 'parent_ids': []}
# {'event': 'on_chain_stream', 'run_id': '883f0b52-c89b-438e-b669-05fc561be994', 'tags': [], 'metadata': {}, 'name': 'mussai_agent', 'data': {'chunk': (AIMessageChunk(content=[{'text': 'BSC ', 'type': 'text', 'index': 0}], additional_kwargs={}, response_metadata={}, id='run-cf7c9016-a081-4b49-9be8-58ac3d0bdb92'), {'langgraph_step': 1, 'langgraph_node': 'node_llm_musseai', 'langgraph_triggers': ('branch:to:node_llm_musseai',), 'langgraph_path': ('__pregel_pull', 'node_llm_musseai'), 'langgraph_checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'llm': 'anthropic_claude_3_5_sonnet', 'checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'ls_provider': 'anthropic', 'ls_model_name': 'claude-3-5-sonnet-20241022', 'ls_model_type': 'chat', 'ls_temperature': 0.9, 'ls_max_tokens': 4096})}, 'parent_ids': []}
# {'event': 'on_chat_model_stream', 'name': 'ChatAnthropic', 'run_id': 'cf7c9016-a081-4b49-9be8-58ac3d0bdb92', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'node_llm_musseai', 'langgraph_triggers': ('branch:to:node_llm_musseai',), 'langgraph_path': ('__pregel_pull', 'node_llm_musseai'), 'langgraph_checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'llm': 'anthropic_claude_3_5_sonnet', 'checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'ls_provider': 'anthropic', 'ls_model_name': 'claude-3-5-sonnet-20241022', 'ls_model_type': 'chat', 'ls_temperature': 0.9, 'ls_max_tokens': 4096}, 'data': {'chunk': AIMessageChunk(content=[{'text': '网络上将', 'type': 'text', 'index': 0}], additional_kwargs={}, response_metadata={}, id='run-cf7c9016-a081-4b49-9be8-58ac3d0bdb92')}, 'parent_ids': []}
# {'event': 'on_chain_stream', 'run_id': '883f0b52-c89b-438e-b669-05fc561be994', 'tags': [], 'metadata': {}, 'name': 'mussai_agent', 'data': {'chunk': (AIMessageChunk(content=[{'text': '网络上将', 'type': 'text', 'index': 0}], additional_kwargs={}, response_metadata={}, id='run-cf7c9016-a081-4b49-9be8-58ac3d0bdb92'), {'langgraph_step': 1, 'langgraph_node': 'node_llm_musseai', 'langgraph_triggers': ('branch:to:node_llm_musseai',), 'langgraph_path': ('__pregel_pull', 'node_llm_musseai'), 'langgraph_checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'llm': 'anthropic_claude_3_5_sonnet', 'checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'ls_provider': 'anthropic', 'ls_model_name': 'claude-3-5-sonnet-20241022', 'ls_model_type': 'chat', 'ls_temperature': 0.9, 'ls_max_tokens': 4096})}, 'parent_ids': []}
# {'event': 'on_chat_model_stream', 'name': 'ChatAnthropic', 'run_id': 'cf7c9016-a081-4b49-9be8-58ac3d0bdb92', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'node_llm_musseai', 'langgraph_triggers': ('branch:to:node_llm_musseai',), 'langgraph_path': ('__pregel_pull', 'node_llm_musseai'), 'langgraph_checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'llm': 'anthropic_claude_3_5_sonnet', 'checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'ls_provider': 'anthropic', 'ls_model_name': 'claude-3-5-sonnet-20241022', 'ls_model_type': 'chat', 'ls_temperature': 0.9, 'ls_max_tokens': 4096}, 'data': {'chunk': AIMessageChunk(content=[{'text': ' 10 ', 'type': 'text', 'index': 0}], additional_kwargs={}, response_metadata={}, id='run-cf7c9016-a081-4b49-9be8-58ac3d0bdb92')}, 'parent_ids': []}
# {'event': 'on_chain_stream', 'run_id': '883f0b52-c89b-438e-b669-05fc561be994', 'tags': [], 'metadata': {}, 'name': 'mussai_agent', 'data': {'chunk': (AIMessageChunk(content=[{'text': ' 10 ', 'type': 'text', 'index': 0}], additional_kwargs={}, response_metadata={}, id='run-cf7c9016-a081-4b49-9be8-58ac3d0bdb92'), {'langgraph_step': 1, 'langgraph_node': 'node_llm_musseai', 'langgraph_triggers': ('branch:to:node_llm_musseai',), 'langgraph_path': ('__pregel_pull', 'node_llm_musseai'), 'langgraph_checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'llm': 'anthropic_claude_3_5_sonnet', 'checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'ls_provider': 'anthropic', 'ls_model_name': 'claude-3-5-sonnet-20241022', 'ls_model_type': 'chat', 'ls_temperature': 0.9, 'ls_max_tokens': 4096})}, 'parent_ids': []}
# {'event': 'on_chat_model_stream', 'name': 'ChatAnthropic', 'run_id': 'cf7c9016-a081-4b49-9be8-58ac3d0bdb92', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'node_llm_musseai', 'langgraph_triggers': ('branch:to:node_llm_musseai',), 'langgraph_path': ('__pregel_pull', 'node_llm_musseai'), 'langgraph_checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'llm': 'anthropic_claude_3_5_sonnet', 'checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'ls_provider': 'anthropic', 'ls_model_name': 'claude-3-5-sonnet-20241022', 'ls_model_type': 'chat', 'ls_temperature': 0.9, 'ls_max_tokens': 4096}, 'data': {'chunk': AIMessageChunk(content=[{'text': 'USDT ', 'type': 'text', 'index': 0}], additional_kwargs={}, response_metadata={}, id='run-cf7c9016-a081-4b49-9be8-58ac3d0bdb92')}, 'parent_ids': []}
# {'event': 'on_chain_stream', 'run_id': '883f0b52-c89b-438e-b669-05fc561be994', 'tags': [], 'metadata': {}, 'name': 'mussai_agent', 'data': {'chunk': (AIMessageChunk(content=[{'text': 'USDT ', 'type': 'text', 'index': 0}], additional_kwargs={}, response_metadata={}, id='run-cf7c9016-a081-4b49-9be8-58ac3d0bdb92'), {'langgraph_step': 1, 'langgraph_node': 'node_llm_musseai', 'langgraph_triggers': ('branch:to:node_llm_musseai',), 'langgraph_path': ('__pregel_pull', 'node_llm_musseai'), 'langgraph_checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'llm': 'anthropic_claude_3_5_sonnet', 'checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'ls_provider': 'anthropic', 'ls_model_name': 'claude-3-5-sonnet-20241022', 'ls_model_type': 'chat', 'ls_temperature': 0.9, 'ls_max_tokens': 4096})}, 'parent_ids': []}
# {'event': 'on_chat_model_stream', 'name': 'ChatAnthropic', 'run_id': 'cf7c9016-a081-4b49-9be8-58ac3d0bdb92', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'node_llm_musseai', 'langgraph_triggers': ('branch:to:node_llm_musseai',), 'langgraph_path': ('__pregel_pull', 'node_llm_musseai'), 'langgraph_checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'llm': 'anthropic_claude_3_5_sonnet', 'checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'ls_provider': 'anthropic', 'ls_model_name': 'claude-3-5-sonnet-20241022', 'ls_model_type': 'chat', 'ls_temperature': 0.9, 'ls_max_tokens': 4096}, 'data': {'chunk': AIMessageChunk(content=[{'text': '跨链', 'type': 'text', 'index': 0}], additional_kwargs={}, response_metadata={}, id='run-cf7c9016-a081-4b49-9be8-58ac3d0bdb92')}, 'parent_ids': []}
# {'event': 'on_chain_stream', 'run_id': '883f0b52-c89b-438e-b669-05fc561be994', 'tags': [], 'metadata': {}, 'name': 'mussai_agent', 'data': {'chunk': (AIMessageChunk(content=[{'text': '跨链', 'type': 'text', 'index': 0}], additional_kwargs={}, response_metadata={}, id='run-cf7c9016-a081-4b49-9be8-58ac3d0bdb92'), {'langgraph_step': 1, 'langgraph_node': 'node_llm_musseai', 'langgraph_triggers': ('branch:to:node_llm_musseai',), 'langgraph_path': ('__pregel_pull', 'node_llm_musseai'), 'langgraph_checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'llm': 'anthropic_claude_3_5_sonnet', 'checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'ls_provider': 'anthropic', 'ls_model_name': 'claude-3-5-sonnet-20241022', 'ls_model_type': 'chat', 'ls_temperature': 0.9, 'ls_max_tokens': 4096})}, 'parent_ids': []}
# {'event': 'on_chat_model_stream', 'name': 'ChatAnthropic', 'run_id': 'cf7c9016-a081-4b49-9be8-58ac3d0bdb92', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'node_llm_musseai', 'langgraph_triggers': ('branch:to:node_llm_musseai',), 'langgraph_path': ('__pregel_pull', 'node_llm_musseai'), 'langgraph_checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'llm': 'anthropic_claude_3_5_sonnet', 'checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'ls_provider': 'anthropic', 'ls_model_name': 'claude-3-5-sonnet-20241022', 'ls_model_type': 'chat', 'ls_temperature': 0.9, 'ls_max_tokens': 4096}, 'data': {'chunk': AIMessageChunk(content=[{'text': '兑换到 ', 'type': 'text', 'index': 0}], additional_kwargs={}, response_metadata={}, id='run-cf7c9016-a081-4b49-9be8-58ac3d0bdb92')}, 'parent_ids': []}
# {'event': 'on_chain_stream', 'run_id': '883f0b52-c89b-438e-b669-05fc561be994', 'tags': [], 'metadata': {}, 'name': 'mussai_agent', 'data': {'chunk': (AIMessageChunk(content=[{'text': '兑换到 ', 'type': 'text', 'index': 0}], additional_kwargs={}, response_metadata={}, id='run-cf7c9016-a081-4b49-9be8-58ac3d0bdb92'), {'langgraph_step': 1, 'langgraph_node': 'node_llm_musseai', 'langgraph_triggers': ('branch:to:node_llm_musseai',), 'langgraph_path': ('__pregel_pull', 'node_llm_musseai'), 'langgraph_checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'llm': 'anthropic_claude_3_5_sonnet', 'checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'ls_provider': 'anthropic', 'ls_model_name': 'claude-3-5-sonnet-20241022', 'ls_model_type': 'chat', 'ls_temperature': 0.9, 'ls_max_tokens': 4096})}, 'parent_ids': []}
# {'event': 'on_chat_model_stream', 'name': 'ChatAnthropic', 'run_id': 'cf7c9016-a081-4b49-9be8-58ac3d0bdb92', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'node_llm_musseai', 'langgraph_triggers': ('branch:to:node_llm_musseai',), 'langgraph_path': ('__pregel_pull', 'node_llm_musseai'), 'langgraph_checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'llm': 'anthropic_claude_3_5_sonnet', 'checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'ls_provider': 'anthropic', 'ls_model_name': 'claude-3-5-sonnet-20241022', 'ls_model_type': 'chat', 'ls_temperature': 0.9, 'ls_max_tokens': 4096}, 'data': {'chunk': AIMessageChunk(content=[{'text': 'Solana 网', 'type': 'text', 'index': 0}], additional_kwargs={}, response_metadata={}, id='run-cf7c9016-a081-4b49-9be8-58ac3d0bdb92')}, 'parent_ids': []}
# {'event': 'on_chain_stream', 'run_id': '883f0b52-c89b-438e-b669-05fc561be994', 'tags': [], 'metadata': {}, 'name': 'mussai_agent', 'data': {'chunk': (AIMessageChunk(content=[{'text': 'Solana 网', 'type': 'text', 'index': 0}], additional_kwargs={}, response_metadata={}, id='run-cf7c9016-a081-4b49-9be8-58ac3d0bdb92'), {'langgraph_step': 1, 'langgraph_node': 'node_llm_musseai', 'langgraph_triggers': ('branch:to:node_llm_musseai',), 'langgraph_path': ('__pregel_pull', 'node_llm_musseai'), 'langgraph_checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'llm': 'anthropic_claude_3_5_sonnet', 'checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'ls_provider': 'anthropic', 'ls_model_name': 'claude-3-5-sonnet-20241022', 'ls_model_type': 'chat', 'ls_temperature': 0.9, 'ls_max_tokens': 4096})}, 'parent_ids': []}
# {'event': 'on_chat_model_stream', 'name': 'ChatAnthropic', 'run_id': 'cf7c9016-a081-4b49-9be8-58ac3d0bdb92', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'node_llm_musseai', 'langgraph_triggers': ('branch:to:node_llm_musseai',), 'langgraph_path': ('__pregel_pull', 'node_llm_musseai'), 'langgraph_checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'llm': 'anthropic_claude_3_5_sonnet', 'checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'ls_provider': 'anthropic', 'ls_model_name': 'claude-3-5-sonnet-20241022', 'ls_model_type': 'chat', 'ls_temperature': 0.9, 'ls_max_tokens': 4096}, 'data': {'chunk': AIMessageChunk(content=[{'text': '络。', 'type': 'text', 'index': 0}], additional_kwargs={}, response_metadata={}, id='run-cf7c9016-a081-4b49-9be8-58ac3d0bdb92')}, 'parent_ids': []}
# {'event': 'on_chain_stream', 'run_id': '883f0b52-c89b-438e-b669-05fc561be994', 'tags': [], 'metadata': {}, 'name': 'mussai_agent', 'data': {'chunk': (AIMessageChunk(content=[{'text': '络。', 'type': 'text', 'index': 0}], additional_kwargs={}, response_metadata={}, id='run-cf7c9016-a081-4b49-9be8-58ac3d0bdb92'), {'langgraph_step': 1, 'langgraph_node': 'node_llm_musseai', 'langgraph_triggers': ('branch:to:node_llm_musseai',), 'langgraph_path': ('__pregel_pull', 'node_llm_musseai'), 'langgraph_checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'llm': 'anthropic_claude_3_5_sonnet', 'checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'ls_provider': 'anthropic', 'ls_model_name': 'claude-3-5-sonnet-20241022', 'ls_model_type': 'chat', 'ls_temperature': 0.9, 'ls_max_tokens': 4096})}, 'parent_ids': []}
# {'event': 'on_chat_model_stream', 'name': 'ChatAnthropic', 'run_id': 'cf7c9016-a081-4b49-9be8-58ac3d0bdb92', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'node_llm_musseai', 'langgraph_triggers': ('branch:to:node_llm_musseai',), 'langgraph_path': ('__pregel_pull', 'node_llm_musseai'), 'langgraph_checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'llm': 'anthropic_claude_3_5_sonnet', 'checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'ls_provider': 'anthropic', 'ls_model_name': 'claude-3-5-sonnet-20241022', 'ls_model_type': 'chat', 'ls_temperature': 0.9, 'ls_max_tokens': 4096}, 'data': {'chunk': AIMessageChunk(content=[{'text': '让我们通', 'type': 'text', 'index': 0}], additional_kwargs={}, response_metadata={}, id='run-cf7c9016-a081-4b49-9be8-58ac3d0bdb92')}, 'parent_ids': []}
# {'event': 'on_chain_stream', 'run_id': '883f0b52-c89b-438e-b669-05fc561be994', 'tags': [], 'metadata': {}, 'name': 'mussai_agent', 'data': {'chunk': (AIMessageChunk(content=[{'text': '让我们通', 'type': 'text', 'index': 0}], additional_kwargs={}, response_metadata={}, id='run-cf7c9016-a081-4b49-9be8-58ac3d0bdb92'), {'langgraph_step': 1, 'langgraph_node': 'node_llm_musseai', 'langgraph_triggers': ('branch:to:node_llm_musseai',), 'langgraph_path': ('__pregel_pull', 'node_llm_musseai'), 'langgraph_checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'llm': 'anthropic_claude_3_5_sonnet', 'checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'ls_provider': 'anthropic', 'ls_model_name': 'claude-3-5-sonnet-20241022', 'ls_model_type': 'chat', 'ls_temperature': 0.9, 'ls_max_tokens': 4096})}, 'parent_ids': []}
# {'event': 'on_chat_model_stream', 'name': 'ChatAnthropic', 'run_id': 'cf7c9016-a081-4b49-9be8-58ac3d0bdb92', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'node_llm_musseai', 'langgraph_triggers': ('branch:to:node_llm_musseai',), 'langgraph_path': ('__pregel_pull', 'node_llm_musseai'), 'langgraph_checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'llm': 'anthropic_claude_3_5_sonnet', 'checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'ls_provider': 'anthropic', 'ls_model_name': 'claude-3-5-sonnet-20241022', 'ls_model_type': 'chat', 'ls_temperature': 0.9, 'ls_max_tokens': 4096}, 'data': {'chunk': AIMessageChunk(content=[{'text': '过几', 'type': 'text', 'index': 0}], additional_kwargs={}, response_metadata={}, id='run-cf7c9016-a081-4b49-9be8-58ac3d0bdb92')}, 'parent_ids': []}
# {'event': 'on_chain_stream', 'run_id': '883f0b52-c89b-438e-b669-05fc561be994', 'tags': [], 'metadata': {}, 'name': 'mussai_agent', 'data': {'chunk': (AIMessageChunk(content=[{'text': '过几', 'type': 'text', 'index': 0}], additional_kwargs={}, response_metadata={}, id='run-cf7c9016-a081-4b49-9be8-58ac3d0bdb92'), {'langgraph_step': 1, 'langgraph_node': 'node_llm_musseai', 'langgraph_triggers': ('branch:to:node_llm_musseai',), 'langgraph_path': ('__pregel_pull', 'node_llm_musseai'), 'langgraph_checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'llm': 'anthropic_claude_3_5_sonnet', 'checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'ls_provider': 'anthropic', 'ls_model_name': 'claude-3-5-sonnet-20241022', 'ls_model_type': 'chat', 'ls_temperature': 0.9, 'ls_max_tokens': 4096})}, 'parent_ids': []}
# {'event': 'on_chat_model_stream', 'name': 'ChatAnthropic', 'run_id': 'cf7c9016-a081-4b49-9be8-58ac3d0bdb92', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'node_llm_musseai', 'langgraph_triggers': ('branch:to:node_llm_musseai',), 'langgraph_path': ('__pregel_pull', 'node_llm_musseai'), 'langgraph_checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'llm': 'anthropic_claude_3_5_sonnet', 'checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'ls_provider': 'anthropic', 'ls_model_name': 'claude-3-5-sonnet-20241022', 'ls_model_type': 'chat', 'ls_temperature': 0.9, 'ls_max_tokens': 4096}, 'data': {'chunk': AIMessageChunk(content=[{'text': '个步骤来', 'type': 'text', 'index': 0}], additional_kwargs={}, response_metadata={}, id='run-cf7c9016-a081-4b49-9be8-58ac3d0bdb92')}, 'parent_ids': []}
# {'event': 'on_chain_stream', 'run_id': '883f0b52-c89b-438e-b669-05fc561be994', 'tags': [], 'metadata': {}, 'name': 'mussai_agent', 'data': {'chunk': (AIMessageChunk(content=[{'text': '个步骤来', 'type': 'text', 'index': 0}], additional_kwargs={}, response_metadata={}, id='run-cf7c9016-a081-4b49-9be8-58ac3d0bdb92'), {'langgraph_step': 1, 'langgraph_node': 'node_llm_musseai', 'langgraph_triggers': ('branch:to:node_llm_musseai',), 'langgraph_path': ('__pregel_pull', 'node_llm_musseai'), 'langgraph_checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'llm': 'anthropic_claude_3_5_sonnet', 'checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'ls_provider': 'anthropic', 'ls_model_name': 'claude-3-5-sonnet-20241022', 'ls_model_type': 'chat', 'ls_temperature': 0.9, 'ls_max_tokens': 4096})}, 'parent_ids': []}
# {'event': 'on_chat_model_stream', 'name': 'ChatAnthropic', 'run_id': 'cf7c9016-a081-4b49-9be8-58ac3d0bdb92', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'node_llm_musseai', 'langgraph_triggers': ('branch:to:node_llm_musseai',), 'langgraph_path': ('__pregel_pull', 'node_llm_musseai'), 'langgraph_checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'llm': 'anthropic_claude_3_5_sonnet', 'checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'ls_provider': 'anthropic', 'ls_model_name': 'claude-3-5-sonnet-20241022', 'ls_model_type': 'chat', 'ls_temperature': 0.9, 'ls_max_tokens': 4096}, 'data': {'chunk': AIMessageChunk(content=[{'text': '完成这个操', 'type': 'text', 'index': 0}], additional_kwargs={}, response_metadata={}, id='run-cf7c9016-a081-4b49-9be8-58ac3d0bdb92')}, 'parent_ids': []}
# {'event': 'on_chain_stream', 'run_id': '883f0b52-c89b-438e-b669-05fc561be994', 'tags': [], 'metadata': {}, 'name': 'mussai_agent', 'data': {'chunk': (AIMessageChunk(content=[{'text': '完成这个操', 'type': 'text', 'index': 0}], additional_kwargs={}, response_metadata={}, id='run-cf7c9016-a081-4b49-9be8-58ac3d0bdb92'), {'langgraph_step': 1, 'langgraph_node': 'node_llm_musseai', 'langgraph_triggers': ('branch:to:node_llm_musseai',), 'langgraph_path': ('__pregel_pull', 'node_llm_musseai'), 'langgraph_checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'llm': 'anthropic_claude_3_5_sonnet', 'checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'ls_provider': 'anthropic', 'ls_model_name': 'claude-3-5-sonnet-20241022', 'ls_model_type': 'chat', 'ls_temperature': 0.9, 'ls_max_tokens': 4096})}, 'parent_ids': []}
# {'event': 'on_chat_model_stream', 'name': 'ChatAnthropic', 'run_id': 'cf7c9016-a081-4b49-9be8-58ac3d0bdb92', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'node_llm_musseai', 'langgraph_triggers': ('branch:to:node_llm_musseai',), 'langgraph_path': ('__pregel_pull', 'node_llm_musseai'), 'langgraph_checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'llm': 'anthropic_claude_3_5_sonnet', 'checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'ls_provider': 'anthropic', 'ls_model_name': 'claude-3-5-sonnet-20241022', 'ls_model_type': 'chat', 'ls_temperature': 0.9, 'ls_max_tokens': 4096}, 'data': {'chunk': AIMessageChunk(content=[{'text': '作。\n\n首先', 'type': 'text', 'index': 0}], additional_kwargs={}, response_metadata={}, id='run-cf7c9016-a081-4b49-9be8-58ac3d0bdb92')}, 'parent_ids': []}
# {'event': 'on_chain_stream', 'run_id': '883f0b52-c89b-438e-b669-05fc561be994', 'tags': [], 'metadata': {}, 'name': 'mussai_agent', 'data': {'chunk': (AIMessageChunk(content=[{'text': '作。\n\n首先', 'type': 'text', 'index': 0}], additional_kwargs={}, response_metadata={}, id='run-cf7c9016-a081-4b49-9be8-58ac3d0bdb92'), {'langgraph_step': 1, 'langgraph_node': 'node_llm_musseai', 'langgraph_triggers': ('branch:to:node_llm_musseai',), 'langgraph_path': ('__pregel_pull', 'node_llm_musseai'), 'langgraph_checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'llm': 'anthropic_claude_3_5_sonnet', 'checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'ls_provider': 'anthropic', 'ls_model_name': 'claude-3-5-sonnet-20241022', 'ls_model_type': 'chat', 'ls_temperature': 0.9, 'ls_max_tokens': 4096})}, 'parent_ids': []}
# {'event': 'on_chat_model_stream', 'name': 'ChatAnthropic', 'run_id': 'cf7c9016-a081-4b49-9be8-58ac3d0bdb92', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'node_llm_musseai', 'langgraph_triggers': ('branch:to:node_llm_musseai',), 'langgraph_path': ('__pregel_pull', 'node_llm_musseai'), 'langgraph_checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'llm': 'anthropic_claude_3_5_sonnet', 'checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'ls_provider': 'anthropic', 'ls_model_name': 'claude-3-5-sonnet-20241022', 'ls_model_type': 'chat', 'ls_temperature': 0.9, 'ls_max_tokens': 4096}, 'data': {'chunk': AIMessageChunk(content=[{'text': '，让', 'type': 'text', 'index': 0}], additional_kwargs={}, response_metadata={}, id='run-cf7c9016-a081-4b49-9be8-58ac3d0bdb92')}, 'parent_ids': []}
# {'event': 'on_chain_stream', 'run_id': '883f0b52-c89b-438e-b669-05fc561be994', 'tags': [], 'metadata': {}, 'name': 'mussai_agent', 'data': {'chunk': (AIMessageChunk(content=[{'text': '，让', 'type': 'text', 'index': 0}], additional_kwargs={}, response_metadata={}, id='run-cf7c9016-a081-4b49-9be8-58ac3d0bdb92'), {'langgraph_step': 1, 'langgraph_node': 'node_llm_musseai', 'langgraph_triggers': ('branch:to:node_llm_musseai',), 'langgraph_path': ('__pregel_pull', 'node_llm_musseai'), 'langgraph_checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'llm': 'anthropic_claude_3_5_sonnet', 'checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'ls_provider': 'anthropic', 'ls_model_name': 'claude-3-5-sonnet-20241022', 'ls_model_type': 'chat', 'ls_temperature': 0.9, 'ls_max_tokens': 4096})}, 'parent_ids': []}
# {'event': 'on_chat_model_stream', 'name': 'ChatAnthropic', 'run_id': 'cf7c9016-a081-4b49-9be8-58ac3d0bdb92', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'node_llm_musseai', 'langgraph_triggers': ('branch:to:node_llm_musseai',), 'langgraph_path': ('__pregel_pull', 'node_llm_musseai'), 'langgraph_checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'llm': 'anthropic_claude_3_5_sonnet', 'checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'ls_provider': 'anthropic', 'ls_model_name': 'claude-3-5-sonnet-20241022', 'ls_model_type': 'chat', 'ls_temperature': 0.9, 'ls_max_tokens': 4096}, 'data': {'chunk': AIMessageChunk(content=[{'text': '我们询', 'type': 'text', 'index': 0}], additional_kwargs={}, response_metadata={}, id='run-cf7c9016-a081-4b49-9be8-58ac3d0bdb92')}, 'parent_ids': []}
# {'event': 'on_chain_stream', 'run_id': '883f0b52-c89b-438e-b669-05fc561be994', 'tags': [], 'metadata': {}, 'name': 'mussai_agent', 'data': {'chunk': (AIMessageChunk(content=[{'text': '我们询', 'type': 'text', 'index': 0}], additional_kwargs={}, response_metadata={}, id='run-cf7c9016-a081-4b49-9be8-58ac3d0bdb92'), {'langgraph_step': 1, 'langgraph_node': 'node_llm_musseai', 'langgraph_triggers': ('branch:to:node_llm_musseai',), 'langgraph_path': ('__pregel_pull', 'node_llm_musseai'), 'langgraph_checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'llm': 'anthropic_claude_3_5_sonnet', 'checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'ls_provider': 'anthropic', 'ls_model_name': 'claude-3-5-sonnet-20241022', 'ls_model_type': 'chat', 'ls_temperature': 0.9, 'ls_max_tokens': 4096})}, 'parent_ids': []}
# {'event': 'on_chat_model_stream', 'name': 'ChatAnthropic', 'run_id': 'cf7c9016-a081-4b49-9be8-58ac3d0bdb92', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'node_llm_musseai', 'langgraph_triggers': ('branch:to:node_llm_musseai',), 'langgraph_path': ('__pregel_pull', 'node_llm_musseai'), 'langgraph_checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'llm': 'anthropic_claude_3_5_sonnet', 'checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'ls_provider': 'anthropic', 'ls_model_name': 'claude-3-5-sonnet-20241022', 'ls_model_type': 'chat', 'ls_temperature': 0.9, 'ls_max_tokens': 4096}, 'data': {'chunk': AIMessageChunk(content=[{'text': '问', 'type': 'text', 'index': 0}], additional_kwargs={}, response_metadata={}, id='run-cf7c9016-a081-4b49-9be8-58ac3d0bdb92')}, 'parent_ids': []}
# {'event': 'on_chain_stream', 'run_id': '883f0b52-c89b-438e-b669-05fc561be994', 'tags': [], 'metadata': {}, 'name': 'mussai_agent', 'data': {'chunk': (AIMessageChunk(content=[{'text': '问', 'type': 'text', 'index': 0}], additional_kwargs={}, response_metadata={}, id='run-cf7c9016-a081-4b49-9be8-58ac3d0bdb92'), {'langgraph_step': 1, 'langgraph_node': 'node_llm_musseai', 'langgraph_triggers': ('branch:to:node_llm_musseai',), 'langgraph_path': ('__pregel_pull', 'node_llm_musseai'), 'langgraph_checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'llm': 'anthropic_claude_3_5_sonnet', 'checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'ls_provider': 'anthropic', 'ls_model_name': 'claude-3-5-sonnet-20241022', 'ls_model_type': 'chat', 'ls_temperature': 0.9, 'ls_max_tokens': 4096})}, 'parent_ids': []}
# {'event': 'on_chat_model_stream', 'name': 'ChatAnthropic', 'run_id': 'cf7c9016-a081-4b49-9be8-58ac3d0bdb92', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'node_llm_musseai', 'langgraph_triggers': ('branch:to:node_llm_musseai',), 'langgraph_path': ('__pregel_pull', 'node_llm_musseai'), 'langgraph_checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'llm': 'anthropic_claude_3_5_sonnet', 'checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'ls_provider': 'anthropic', 'ls_model_name': 'claude-3-5-sonnet-20241022', 'ls_model_type': 'chat', 'ls_temperature': 0.9, 'ls_max_tokens': 4096}, 'data': {'chunk': AIMessageChunk(content=[{'text': '跨链兑换', 'type': 'text', 'index': 0}], additional_kwargs={}, response_metadata={}, id='run-cf7c9016-a081-4b49-9be8-58ac3d0bdb92')}, 'parent_ids': []}
# {'event': 'on_chain_stream', 'run_id': '883f0b52-c89b-438e-b669-05fc561be994', 'tags': [], 'metadata': {}, 'name': 'mussai_agent', 'data': {'chunk': (AIMessageChunk(content=[{'text': '跨链兑换', 'type': 'text', 'index': 0}], additional_kwargs={}, response_metadata={}, id='run-cf7c9016-a081-4b49-9be8-58ac3d0bdb92'), {'langgraph_step': 1, 'langgraph_node': 'node_llm_musseai', 'langgraph_triggers': ('branch:to:node_llm_musseai',), 'langgraph_path': ('__pregel_pull', 'node_llm_musseai'), 'langgraph_checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'llm': 'anthropic_claude_3_5_sonnet', 'checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'ls_provider': 'anthropic', 'ls_model_name': 'claude-3-5-sonnet-20241022', 'ls_model_type': 'chat', 'ls_temperature': 0.9, 'ls_max_tokens': 4096})}, 'parent_ids': []}
# {'event': 'on_chat_model_stream', 'name': 'ChatAnthropic', 'run_id': 'cf7c9016-a081-4b49-9be8-58ac3d0bdb92', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'node_llm_musseai', 'langgraph_triggers': ('branch:to:node_llm_musseai',), 'langgraph_path': ('__pregel_pull', 'node_llm_musseai'), 'langgraph_checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'llm': 'anthropic_claude_3_5_sonnet', 'checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'ls_provider': 'anthropic', 'ls_model_name': 'claude-3-5-sonnet-20241022', 'ls_model_type': 'chat', 'ls_temperature': 0.9, 'ls_max_tokens': 4096}, 'data': {'chunk': AIMessageChunk(content=[{'text': '专家来', 'type': 'text', 'index': 0}], additional_kwargs={}, response_metadata={}, id='run-cf7c9016-a081-4b49-9be8-58ac3d0bdb92')}, 'parent_ids': []}
# {'event': 'on_chain_stream', 'run_id': '883f0b52-c89b-438e-b669-05fc561be994', 'tags': [], 'metadata': {}, 'name': 'mussai_agent', 'data': {'chunk': (AIMessageChunk(content=[{'text': '专家来', 'type': 'text', 'index': 0}], additional_kwargs={}, response_metadata={}, id='run-cf7c9016-a081-4b49-9be8-58ac3d0bdb92'), {'langgraph_step': 1, 'langgraph_node': 'node_llm_musseai', 'langgraph_triggers': ('branch:to:node_llm_musseai',), 'langgraph_path': ('__pregel_pull', 'node_llm_musseai'), 'langgraph_checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'llm': 'anthropic_claude_3_5_sonnet', 'checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'ls_provider': 'anthropic', 'ls_model_name': 'claude-3-5-sonnet-20241022', 'ls_model_type': 'chat', 'ls_temperature': 0.9, 'ls_max_tokens': 4096})}, 'parent_ids': []}
# {'event': 'on_chat_model_stream', 'name': 'ChatAnthropic', 'run_id': 'cf7c9016-a081-4b49-9be8-58ac3d0bdb92', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'node_llm_musseai', 'langgraph_triggers': ('branch:to:node_llm_musseai',), 'langgraph_path': ('__pregel_pull', 'node_llm_musseai'), 'langgraph_checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'llm': 'anthropic_claude_3_5_sonnet', 'checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'ls_provider': 'anthropic', 'ls_model_name': 'claude-3-5-sonnet-20241022', 'ls_model_type': 'chat', 'ls_temperature': 0.9, 'ls_max_tokens': 4096}, 'data': {'chunk': AIMessageChunk(content=[{'text': '处理这个请', 'type': 'text', 'index': 0}], additional_kwargs={}, response_metadata={}, id='run-cf7c9016-a081-4b49-9be8-58ac3d0bdb92')}, 'parent_ids': []}
# {'event': 'on_chain_stream', 'run_id': '883f0b52-c89b-438e-b669-05fc561be994', 'tags': [], 'metadata': {}, 'name': 'mussai_agent', 'data': {'chunk': (AIMessageChunk(content=[{'text': '处理这个请', 'type': 'text', 'index': 0}], additional_kwargs={}, response_metadata={}, id='run-cf7c9016-a081-4b49-9be8-58ac3d0bdb92'), {'langgraph_step': 1, 'langgraph_node': 'node_llm_musseai', 'langgraph_triggers': ('branch:to:node_llm_musseai',), 'langgraph_path': ('__pregel_pull', 'node_llm_musseai'), 'langgraph_checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'llm': 'anthropic_claude_3_5_sonnet', 'checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'ls_provider': 'anthropic', 'ls_model_name': 'claude-3-5-sonnet-20241022', 'ls_model_type': 'chat', 'ls_temperature': 0.9, 'ls_max_tokens': 4096})}, 'parent_ids': []}
# {'event': 'on_chat_model_stream', 'name': 'ChatAnthropic', 'run_id': 'cf7c9016-a081-4b49-9be8-58ac3d0bdb92', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'node_llm_musseai', 'langgraph_triggers': ('branch:to:node_llm_musseai',), 'langgraph_path': ('__pregel_pull', 'node_llm_musseai'), 'langgraph_checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'llm': 'anthropic_claude_3_5_sonnet', 'checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'ls_provider': 'anthropic', 'ls_model_name': 'claude-3-5-sonnet-20241022', 'ls_model_type': 'chat', 'ls_temperature': 0.9, 'ls_max_tokens': 4096}, 'data': {'chunk': AIMessageChunk(content=[{'text': '求：', 'type': 'text', 'index': 0}], additional_kwargs={}, response_metadata={}, id='run-cf7c9016-a081-4b49-9be8-58ac3d0bdb92')}, 'parent_ids': []}
# ...
# {'event': 'on_chain_stream', 'name': 'node_llm_musseai', 'run_id': '10cbd2d4-2c58-4334-92e3-54d1a557784d', 'tags': ['graph:step:5'], 'metadata': {'langgraph_step': 5, 'langgraph_node': 'node_llm_musseai', 'langgraph_triggers': ('branch:to:node_llm_musseai',), 'langgraph_path': ('__pregel_pull', 'node_llm_musseai'), 'langgraph_checkpoint_ns': 'node_llm_musseai:5ec82deb-ef14-21f9-d90d-6872cc58b2b1'}, 'data': {'chunk': {'messages': [HumanMessage(content='帮我从bsc上兑换10u到Solana', additional_kwargs={}, response_metadata={}, id='052c4429-9203-4d5c-97b5-89627774c8eb'), AIMessage(content=[{'text': '我将帮您完成从 BSC 网络上将 10 USDT 跨链兑换到 Solana 网络。让我们通过几个步骤来完成这个操作。\n\n首先，让我们询问跨链兑换专家来处理这个请求：', 'type': 'text', 'index': 0}, {'id': 'toolu_0131UbEbEwqjGtZZcrXuuGCF', 'input': {}, 'name': 'route_to_swap_agent', 'type': 'tool_use', 'index': 1, 'partial_json': ''}], additional_kwargs={}, response_metadata={'stop_reason': 'tool_use', 'stop_sequence': None}, id='run-cf7c9016-a081-4b49-9be8-58ac3d0bdb92', tool_calls=[{'name': 'route_to_swap_agent', 'args': {}, 'id': 'toolu_0131UbEbEwqjGtZZcrXuuGCF', 'type': 'tool_call'}], usage_metadata={'input_tokens': 2735, 'output_tokens': 125, 'total_tokens': 2860, 'input_token_details': {'cache_creation': 0, 'cache_read': 0}}), ToolMessage(content='Now requesting a Cryptocurrency Swap Expert.', name='route_to_swap_agent', id='f1ee4bd5-98b4-4d2b-a524-9f5cab0220e2', tool_call_id='toolu_0131UbEbEwqjGtZZcrXuuGCF'), AIMessage(content=[{'text': '1. 首先，让我们确认可用的代币列表：', 'type': 'text', 'index': 0}, {'id': 'toolu_01SVE8x4o5oaeA6rXvLQ9XzB', 'input': {}, 'name': 'get_available_tokens', 'type': 'tool_use', 'index': 1, 'partial_json': ''}], additional_kwargs={}, response_metadata={'stop_reason': 'tool_use', 'stop_sequence': None}, id='run-e0e95559-524c-4bf4-807d-3d53d75ebfc5', tool_calls=[{'name': 'get_available_tokens', 'args': {}, 'id': 'toolu_01SVE8x4o5oaeA6rXvLQ9XzB', 'type': 'tool_call'}], usage_metadata={'input_tokens': 3628, 'output_tokens': 61, 'total_tokens': 3689, 'input_token_details': {'cache_creation': 0, 'cache_read': 0}}), ToolMessage(content='[{"symbol": "BTC", "name": "BTC", "address": "0xeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee", "decimals": 8, "logoURI": null, "chain": "BTC", "isCrossEnable": 1, "withdrawGas": 1000, "chainId": null}, {"symbol": "ETH", "name": "ETH", "address": "0xeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee", "decimals": 18, "logoURI": null, "chain": "ETH", "isCrossEnable": 1, "withdrawGas": 1000, "chainId": "1"}, {"symbol": "USDC", "name": "USDC", "address": "0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48", "decimals": 6, "logoURI": "", "chain": "ETH", "isCrossEnable": 1, "withdrawGas": 1000, "chainId": "1"}, {"symbol": "TRX", "name": "TRX", "address": "0xeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee", "decimals": 6, "logoURI": "", "chain": "TRON", "isCrossEnable": 1, "withdrawGas": 1000, "chainId": "195"}, {"symbol": "SWFTC", "name": "SWFTC", "address": "0x0bb217E40F8a5Cb79Adf04E1aAb60E5abd0dfC1e", "decimals": 8, "logoURI": null, "chain": "ETH", "isCrossEnable": 1, "withdrawGas": 1000, "chainId": "1"}, {"symbol": "KNC", "name": "KNC", "address": "0xdefa4e8a7bcba345f687a2f1456f5edd9ce97202", "decimals": 18, "logoURI": "", "chain": "ETH", "isCrossEnable": 1, "withdrawGas": 1000, "chainId": "1"}, {"symbol": "ZRX", "name": "ZRX", "address": "0xe41d2489571d322189246dafa5ebde1f4699f498", "decimals": 18, "logoURI": "", "chain": "ETH", "isCrossEnable": 1, "withdrawGas": 1000, "chainId": "1"}, {"symbol": "CVC", "name": "CVC", "address": "0x41e5560054824ea6b0732e656e3ad64e20e94e45", "decimals": 8, "logoURI": "", "chain": "ETH", "isCrossEnable": 1, "withdrawGas": 1000, "chainId": "1"}, {"symbol": "BCH", "name": "BCH", "address": "0xeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee", "decimals": 8, "logoURI": null, "chain": "BCH", "isCrossEnable": 1, "withdrawGas": 1000, "chainId": null}, {"symbol": "GOOCHAIN(ERC20)", "name": "GOOCHAIN(ERC20)", "address": "0xDcB9FF81013c31FF686154B4502eF6BFaA102D2D", "decimals": 8, "logoURI": "", ...
# {'event': 'on_chain_end', 'name': 'node_llm_musseai', 'run_id': '10cbd2d4-2c58-4334-92e3-54d1a557784d', 'tags': ['graph:step:5'], 'metadata': {'langgraph_step': 5, 'langgraph_node': 'node_llm_musseai', 'langgraph_triggers': ('branch:to:node_llm_musseai',), 'langgraph_path': ('__pregel_pull', 'node_llm_musseai'), 'langgraph_checkpoint_ns': 'node_llm_musseai:5ec82deb-ef14-21f9-d90d-6872cc58b2b1'}, 'data': {'input': {'messages': [HumanMessage(content='帮我从bsc上兑换10u到Solana', additional_kwargs={}, response_metadata={}, id='052c4429-9203-4d5c-97b5-89627774c8eb'), AIMessage(content=[{'text': '我将帮您完成从 BSC 网络上将 10 USDT 跨链兑换到 Solana 网络。让我们通过几个步骤来完成这个操作。\n\n首先，让我们询问跨链兑换专家来处理这个请求：', 'type': 'text', 'index': 0}, {'id': 'toolu_0131UbEbEwqjGtZZcrXuuGCF', 'input': {}, 'name': 'route_to_swap_agent', 'type': 'tool_use', 'index': 1, 'partial_json': ''}], additional_kwargs={}, response_metadata={'stop_reason': 'tool_use', 'stop_sequence': None}, id='run-cf7c9016-a081-4b49-9be8-58ac3d0bdb92', tool_calls=[{'name': 'route_to_swap_agent', 'args': {}, 'id': 'toolu_0131UbEbEwqjGtZZcrXuuGCF', 'type': 'tool_call'}], usage_metadata={'input_tokens': 2735, 'output_tokens': 125, 'total_tokens': 2860, 'input_token_details': {'cache_creation': 0, 'cache_read': 0}}), ToolMessage(content='Now requesting a Cryptocurrency Swap Expert.', name='route_to_swap_agent', id='f1ee4bd5-98b4-4d2b-a524-9f5cab0220e2', tool_call_id='toolu_0131UbEbEwqjGtZZcrXuuGCF'), AIMessage(content=[{'text': '1. 首先，让我们确认可用的代币列表：', 'type': 'text', 'index': 0}, {'id': 'toolu_01SVE8x4o5oaeA6rXvLQ9XzB', 'input': {}, 'name': 'get_available_tokens', 'type': 'tool_use', 'index': 1, 'partial_json': ''}], additional_kwargs={}, response_metadata={'stop_reason': 'tool_use', 'stop_sequence': None}, id='run-e0e95559-524c-4bf4-807d-3d53d75ebfc5', tool_calls=[{'name': 'get_available_tokens', 'args': {}, 'id': 'toolu_01SVE8x4o5oaeA6rXvLQ9XzB', 'type': 'tool_call'}], usage_metadata={'input_tokens': 3628, 'output_tokens': 61, 'total_tokens': 3689, 'input_token_details': {'cache_creation': 0, 'cache_read': 0}}), ToolMessage(content='[{"symbol": "BTC", "name": "BTC", "address": "0xeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee", "decimals": 8, "logoURI": null, "chain": "BTC", "isCrossEnable": 1, "withdrawGas": 1000, "chainId": null}, {"symbol": "ETH", "name": "ETH", "address": "0xeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee", "decimals": 18, "logoURI": null, "chain": "ETH", "isCrossEnable": 1, "withdrawGas": 1000, "chainId": "1"}, {"symbol": "USDC", "name": "USDC", "address": "0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48", "decimals": 6, "logoURI": "", "chain": "ETH", "isCrossEnable": 1, "withdrawGas": 1000, "chainId": "1"}, {"symbol": "TRX", "name": "TRX", "address": "0xeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee", "decimals": 6, "logoURI": "", "chain": "TRON", "isCrossEnable": 1, "withdrawGas": 1000, "chainId": "195"}, {"symbol": "SWFTC", "name": "SWFTC", "address": "0x0bb217E40F8a5Cb79Adf04E1aAb60E5abd0dfC1e", "decimals": 8, "logoURI": null, "chain": "ETH", "isCrossEnable": 1, "withdrawGas": 1000, "chainId": "1"}, {"symbol": "KNC", "name": "KNC", "address": "0xdefa4e8a7bcba345f687a2f1456f5edd9ce97202", "decimals": 18, "logoURI": "", "chain": "ETH", "isCrossEnable": 1, "withdrawGas": 1000, "chainId": "1"}, {"symbol": "ZRX", "name": "ZRX", "address": "0xe41d2489571d322189246dafa5ebde1f4699f498", "decimals": 18, "logoURI": "", "chain": "ETH", "isCrossEnable": 1, "withdrawGas": 1000, "chainId": "1"}, {"symbol": "CVC", "name": "CVC", "address": "0x41e5560054824ea6b0732e656e3ad64e20e94e45", "decimals": 8, "logoURI": "", "chain": "ETH", "isCrossEnable": 1, "withdrawGas": 1000, "chainId": "1"}, {"symbol": "BCH", "name": "BCH", "address": "0xeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee", "decimals": 8, "logoURI": null, "chain": "BCH", "isCrossEnable": 1, "withdrawGas": 1000, "chainId": null}, {"symbol": "GOOCHAIN(ERC20)", "name": "GOOCHAIN(ERC20)", "address": "0xDcB9FF81013c31FF686154B4502eF6BFaA102D2D", "decimals": 8, "logoURI": "", "c ...
# {'event': 'on_chain_end', 'name': 'mussai_agent', 'run_id': '883f0b52-c89b-438e-b669-05fc561be994', 'tags': [], 'metadata': {}, 'data': {'output': (AIMessageChunk(content=[], additional_kwargs={}, response_metadata={}, id='run-cf7c9016-a081-4b49-9be8-58ac3d0bdb92', usage_metadata={'input_tokens': 2735, 'output_tokens': 2, 'total_tokens': 2737, 'input_token_details': {'cache_creation': 0, 'cache_read': 0}}), {'langgraph_step': 1, 'langgraph_node': 'node_llm_musseai', 'langgraph_triggers': ('branch:to:node_llm_musseai',), 'langgraph_path': ('__pregel_pull', 'node_llm_musseai'), 'langgraph_checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'llm': 'anthropic_claude_3_5_sonnet', 'checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'ls_provider': 'anthropic', 'ls_model_name': 'claude-3-5-sonnet-20241022', 'ls_model_type': 'chat', 'ls_temperature': 0.9, 'ls_max_tokens': 4096}, AIMessageChunk(content=[{'text': '我', 'type': 'text', 'index': 0}], additional_kwargs={}, response_metadata={}, id='run-cf7c9016-a081-4b49-9be8-58ac3d0bdb92'), {'langgraph_step': 1, 'langgraph_node': 'node_llm_musseai', 'langgraph_triggers': ('branch:to:node_llm_musseai',), 'langgraph_path': ('__pregel_pull', 'node_llm_musseai'), 'langgraph_checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'llm': 'anthropic_claude_3_5_sonnet', 'checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'ls_provider': 'anthropic', 'ls_model_name': 'claude-3-5-sonnet-20241022', 'ls_model_type': 'chat', 'ls_temperature': 0.9, 'ls_max_tokens': 4096}, AIMessageChunk(content=[{'text': '将', 'type': 'text', 'index': 0}], additional_kwargs={}, response_metadata={}, id='run-cf7c9016-a081-4b49-9be8-58ac3d0bdb92'), {'langgraph_step': 1, 'langgraph_node': 'node_llm_musseai', 'langgraph_triggers': ('branch:to:node_llm_musseai',), 'langgraph_path': ('__pregel_pull', 'node_llm_musseai'), 'langgraph_checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'llm': 'anthropic_claude_3_5_sonnet', 'checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'ls_provider': 'anthropic', 'ls_model_name': 'claude-3-5-sonnet-20241022', 'ls_model_type': 'chat', 'ls_temperature': 0.9, 'ls_max_tokens': 4096}, AIMessageChunk(content=[{'text': '帮您完', 'type': 'text', 'index': 0}], additional_kwargs={}, response_metadata={}, id='run-cf7c9016-a081-4b49-9be8-58ac3d0bdb92'), {'langgraph_step': 1, 'langgraph_node': 'node_llm_musseai', 'langgraph_triggers': ('branch:to:node_llm_musseai',), 'langgraph_path': ('__pregel_pull', 'node_llm_musseai'), 'langgraph_checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'llm': 'anthropic_claude_3_5_sonnet', 'checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'ls_provider': 'anthropic', 'ls_model_name': 'claude-3-5-sonnet-20241022', 'ls_model_type': 'chat', 'ls_temperature': 0.9, 'ls_max_tokens': 4096}, AIMessageChunk(content=[{'text': '成从 ', 'type': 'text', 'index': 0}], additional_kwargs={}, response_metadata={}, id='run-cf7c9016-a081-4b49-9be8-58ac3d0bdb92'), {'langgraph_step': 1, 'langgraph_node': 'node_llm_musseai', 'langgraph_triggers': ('branch:to:node_llm_musseai',), 'langgraph_path': ('__pregel_pull', 'node_llm_musseai'), 'langgraph_checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'llm': 'anthropic_claude_3_5_sonnet', 'checkpoint_ns': 'node_llm_musseai:c8b3d460-cc4b-1041-458c-28b40ea9bf9f', 'ls_provider': 'anthropic', 'ls_model_name': 'claude-3-5-sonnet-20241022', 'ls_model_type': 'chat', 'ls_temperature': 0.9, 'ls_max_tokens': 4096}, AIMessageChunk(content=[{'text': 'BSC ', 'type': 'text', 'index': 0}], additional_kwargs={}, response_metadata={}, id='run-cf7c9016-a081-4b49-9be8-58ac3d0bdb92'), {'langgraph_step': 1, 'langgraph_node': 'node_llm_musseai', 'langgraph_triggers': ('branch:to:node_llm_musseai',), 'langgraph_path': ('__pregel_pull', 'node_llm_musseai'), 'langgraph_checkpoint_ns': 'node_ll ...
