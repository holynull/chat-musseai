# %%
# %%bash
#  export HTTP_PROXY=http://127.0.0.1:7890
#  export HTTPS_PROXY=http://127.0.0.1:7890
#  export NO_PROXY=localhost,127.0.0.1

# %%
from dotenv import load_dotenv

load_dotenv('.env')
# Out:
# True

# %%
from backend.graphs.graph_swap import graph
from IPython.display import Image, display

try:
    display(Image(graph.get_graph().draw_mermaid_png()))
except Exception:
    # This requires some extra dependencies and is optional
    pass

# %%
from backend.graphs.graph_wallet import graph
from IPython.display import Image, display

try:
    display(Image(graph.get_graph().draw_mermaid_png()))
except Exception:
    # This requires some extra dependencies and is optional
    pass

# %%
from backend.graphs.graph_search import graph
from IPython.display import Image, display

try:
    display(Image(graph.get_graph().draw_mermaid_png()))
except Exception:
    # This requires some extra dependencies and is optional
    pass
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.

# %%
from backend.graphs.graph_quote import graph
from IPython.display import Image, display

try:
    display(Image(graph.get_graph().draw_mermaid_png()))
except Exception:
    # This requires some extra dependencies and is optional
    pass

# %%
from backend.graphs.graph_image import graph
from IPython.display import Image, display

try:
    display(Image(graph.get_graph().draw_mermaid_png()))
except Exception:
    # This requires some extra dependencies and is optional
    pass

# %%
from backend.graphs.graph_chatbot import graph
from IPython.display import Image, display

try:
    display(Image(graph.get_graph().draw_mermaid_png()))
except Exception:
    # This requires some extra dependencies and is optional
    pass

# %%
chunks = graph.astream_events(
    {
        "messages": {"type": "human", "content": "画一只小猫爬树"},
        "wallet_is_connected": False,
        "chain_id": -1,
        "wallet_address": None,
		"time_zone":"Asia/Shanghai",
        "llm": "anthropic_claude_3_5_sonnet",
    },
    version="v1",
    stream_mode="messages",
)
from typing import List
from langchain_core.messages import AIMessage

async for chunk in chunks:
    print(chunk)
    if chunk["event"] == "on_chain_stream":
        # print(chunk)
        if "data" in chunk:
            # print(chunk["data"])
            data = chunk["data"]
            # print(data["chunk"])
            # if "messages" in data["chunk"]:
            #     messages = data["chunk"]["messages"]
            #     # print(f"messages are {messages}")
            #     if isinstance(messages, List) and isinstance(messages[0], AIMessage):
            #         print(f"{messages[0].content[0]['text']}")
# Out:
# {'event': 'on_chain_start', 'run_id': '115196e1-a30f-4c5f-8682-91accafd5951', 'name': 'LangGraph', 'tags': [], 'metadata': {}, 'data': {'input': {'messages': {'type': 'human', 'content': '画一只小猫爬树'}, 'wallet_is_connected': False, 'chain_id': -1, 'wallet_address': None, 'time_zone': 'Asia/Shanghai', 'llm': 'anthropic_claude_3_5_sonnet'}}, 'parent_ids': []}
# {'event': 'on_chain_start', 'name': '__start__', 'run_id': '1cf538b3-15b5-40de-82d1-75e25789bc66', 'tags': ['graph:step:0', 'langsmith:hidden'], 'metadata': {'langgraph_step': 0, 'langgraph_node': '__start__', 'langgraph_triggers': ['__start__'], 'langgraph_path': ('__pregel_pull', '__start__'), 'langgraph_checkpoint_ns': '__start__:87ad22a6-1965-a90c-4367-5eef541a9bd1'}, 'data': {'input': {'messages': {'type': 'human', 'content': '画一只小猫爬树'}, 'wallet_is_connected': False, 'chain_id': -1, 'wallet_address': None, 'time_zone': 'Asia/Shanghai', 'llm': 'anthropic_claude_3_5_sonnet'}}, 'parent_ids': []}
# ...
